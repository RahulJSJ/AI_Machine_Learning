# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import f1_score

# %%
hg = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/housing.csv')

# %%
hg
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
hg.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05

# %%
hg.isnull().sum()  # or isna()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# dtype: int64

# %%
hg.rename(columns={'Avg. Area Income':'avg_area_inc', 'Avg. Area House Age':'avg_area_house_age', 'Avg. Area Number of Rooms':'avg_area _number_of_rooms', 'Avg. Area Number of Bedrooms':'avg_area_number_of_bedrooms', 'Area Population':'area_population'}, inplace=True)
hg
# Out:
#       avg_area_inc  avg_area_house_age  avg_area _number_of_rooms  \
# 0      79545.45857            5.682861                   7.009188
# 1      79248.64245            6.002900                   6.730821
# 2      61287.06718            5.865890                   8.512727
# 3      63345.24005            7.188236                   5.586729
# 4      59982.19723            5.040555                   7.839388
# ...            ...                 ...                        ...
# 4995   60567.94414            7.830362                   6.137356
# 4996   78491.27543            6.999135                   6.576763
# 4997   63390.68689            7.250591                   4.805081
# 4998   68001.33124            5.534388                   7.130144
# 4999   65510.58180            5.992305                   6.792336
#
#       avg_area_number_of_bedrooms  area_population         Price
# 0                            4.09      23086.80050  1.059034e+06
# ...

# %%
regression = LinearRegression()
regression.fit(hg[["avg_area_inc"]],hg.Price)
# Out:
# LinearRegression()

# %%
regression.predict([[79545.45857]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1464424.95032392])

# %%
regression.coef_
# Out:
# array([21.19548317])

# %%
x=hg.drop(columns = "Price")
y = hg["Price"]
x
# Out:
#       avg_area_inc  avg_area_house_age  avg_area _number_of_rooms  \
# 0      79545.45857            5.682861                   7.009188
# 1      79248.64245            6.002900                   6.730821
# 2      61287.06718            5.865890                   8.512727
# 3      63345.24005            7.188236                   5.586729
# 4      59982.19723            5.040555                   7.839388
# ...            ...                 ...                        ...
# 4995   60567.94414            7.830362                   6.137356
# 4996   78491.27543            6.999135                   6.576763
# 4997   63390.68689            7.250591                   4.805081
# 4998   68001.33124            5.534388                   7.130144
# 4999   65510.58180            5.992305                   6.792336
#
#       avg_area_number_of_bedrooms  area_population
# 0                            4.09      23086.80050
# 1                            3.09      40173.07217
# ...

# %%
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state=0)

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regression.intercept_
# Out:
# -2646630.531088097

# %%
regression.coef_
# Out:
# array([2.16604083e+01, 1.65809651e+05, 1.20329408e+05, 2.19309558e+03,
#        1.52858855e+01])

# %%
y_prediction = regression.predict(x_train)
y_prediction
# Out:
# array([1824063.69373585, 1871944.87830113, 1712410.22596439, ...,
#        1048618.24573297,  808586.12948913, 1664071.8073873 ])

# %%
plt.scatter(y_train,y_prediction)

# %%
y_pred_test = regression.predict(x_test)

# %%
plt.scatter(y_test,y_pred_test)
