# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Encoding categorical data
# The ordinal encoding is used to work on ordinal categorical data.
# The second is one hot encoding which works on nominal data.
#
# Data can be classified into two types
#
# Nominal(no intrensic order) and Ordinal (intrensic order)

# %% [markdown]
# ## Label encoding
#
# It is a technique of converting categorical data into numerical data

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/convert.csv')

# %%
df
# Out:
#     age  gender   review education purchased
# 0    30  Female  Average    School        No
# 1    68  Female     Poor        UG        No
# 2    70  Female     Good        PG        No
# 3    72  Female     Good        PG        No
# 4    16  Female  Average        UG        No
# 5    31  Female  Average    School       Yes
# 6    18    Male     Good    School        No
# 7    60  Female     Poor    School       Yes
# 8    65  Female  Average        UG        No
# 9    74    Male     Good        UG       Yes
# 10   98  Female     Good        UG       Yes
# 11   74    Male     Good        UG       Yes
# 12   51    Male     Poor    School        No
# 13   57  Female  Average    School        No
# 14   15    Male     Poor        PG       Yes
# 15   75    Male     Poor        UG        No
# 16   59    Male     Poor        UG       Yes
# 17   22  Female     Poor        UG       Yes
# 18   19    Male     Good    School        No
# 19   97    Male     Poor        PG       Yes
# ...

# %%
df = df.iloc[:,2:]

# %%
df.head()
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
ord.fit(x_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
x_train=ord.transform(x_train)
x_test=ord.transform(x_test)

# %%
x_train
# Out:
# array([[2., 0.],
#        [1., 1.],
#        [0., 1.],
#        [2., 1.],
#        [1., 1.],
#        [0., 2.],
#        [0., 2.],
#        [2., 0.],
#        [0., 0.],
#        [2., 2.],
#        [0., 1.],
#        [1., 0.],
#        [2., 1.],
#        [1., 2.],
#        [1., 0.],
#        [1., 0.],
#        [0., 0.],
#        [2., 1.],
#        [1., 0.],
#        [1., 1.],
#        [0., 2.],
#        [2., 1.],
#        [0., 1.],
#        [0., 2.],
#        [0., 2.],
#        [2., 1.],
#        [2., 2.],
#        [1., 2.],
#        [2., 0.],
#        [1., 1.],
#        [2., 2.],
#        [1., 1.],
#        [0., 2.],
#        [1., 1.],
#        [2., 0.],
#        [2., 0.],
#        [0., 0.],
#        [0., 2.],
#        [0., 1.],
#        [2., 2.]])

# %%
ord.categories_
# Out:
# [array(['Poor', 'Average', 'Good'], dtype=object),
#  array(['School', 'UG', 'PG'], dtype=object)]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %% [markdown]
# ## One hot encoding
# # It is a technique to encode a categorical data into a numerical data by the help of vectorization.
#
# 1. It allows the use of categorical variables in models that require numerical input.
# 2. It can improve model performance by providing more information to the model about the categorical variable.
# 3. It can help to avoid the problem of ordinality, which can occur when a categorical variable has a natural ordering (e.g. “small”, “medium”, “large”).
#
#
#
#
# 1. It can lead to increased dimensionality, as a separate column is created for
# each category in the variable. This can make the model more complex and slow to train.
#
# 2. It can lead to sparse data, as most observations will have a value of 0 in most of the one-hot encoded columns.
#
# 3. It can lead to overfitting, especially if there are many categories in the variable and the sample size is relatively small.
#
# 4. One-hot-encoding is a powerful technique to treat categorical data, but it can lead to increased dimensionality, sparsity, and overfitting. It is important to use it cautiously and consider other methods such as ordinal encoding or binary encoding.

# %%
data = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/cars.csv')

# %%
import seaborn as sns
import numpy as np

# %%
data.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
sns.countplot(data=data, x="owner")
# Out:
# <Axes: xlabel='owner', ylabel='count'>

# %% [markdown]
# Obviously you can use value_count but why not countplot

# %% [markdown]
# ## Pandas One hot encoding

# %%
pd.get_dummies(data,columns=['fuel','owner'])  #The get_dummies() creates 
#the dummy colums holding each category of data in the original column.
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000         0            1         0
# 1       Skoda     120000         370000         0            1         0
# 2       Honda     140000         158000         0            0         0
# 3     Hyundai     127000         225000         0            1         0
# 4      Maruti     120000         130000         0            0         0
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000         0            0         0
# 8124  Hyundai     119000         135000         0            1         0
# 8125   Maruti     120000         382000         0            1         0
# 8126     Tata      25000         290000         0            1         0
# 8127     Tata      25000         290000         0            1         0
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# ...

# %% [markdown]
# ## k-1 one hot encoding

# %%
pd.get_dummies(data,columns=['fuel','owner'],drop_first=True)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000            1         0            0
# 1       Skoda     120000         370000            1         0            0
# 2       Honda     140000         158000            0         0            1
# 3     Hyundai     127000         225000            1         0            0
# 4      Maruti     120000         130000            0         0            1
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000            0         0            1
# 8124  Hyundai     119000         135000            1         0            0
# 8125   Maruti     120000         382000            1         0            0
# 8126     Tata      25000         290000            1         0            0
# 8127     Tata      25000         290000            1         0            0
#
# ...

# %% [markdown]
# # This drops the first dummy column as it may be the base data for example in the owners column the category='first owner' is not an necessity as without the first owner this dataset is impossible to be created

# %% [markdown]
# ## One hot encoding using sklearn module

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
x,x_,y,y_=train_test_split(data.iloc[:,0:4],data.iloc[:,-1],test_size=0.2,random_state=2)

# %%
ohencode = OneHotEncoder(drop='first',sparse=False,dtype=np.int32)

# %%
x_new =ohencode.fit_transform(x[['fuel','owner']])
x_test_new = ohencode.fit_transform(x_[['fuel','owner']])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
x_new.shape
# Out:
# (6502, 7)

# %%
x_test_new.shape
# Out:
# (1626, 7)

# %%
np.hstack((x[['brand','km_driven']].values,x_new))
# Out:
# array([['Hyundai', 35000, 1, ..., 0, 0, 0],
#        ['Jeep', 60000, 1, ..., 0, 0, 0],
#        ['Hyundai', 25000, 0, ..., 0, 0, 0],
#        ...,
#        ['Tata', 15000, 0, ..., 0, 0, 0],
#        ['Maruti', 32500, 1, ..., 1, 0, 0],
#        ['Isuzu', 121000, 1, ..., 0, 0, 0]], dtype=object)

# %% [markdown]
# hstack of numpy is used for concatenation

# %% [markdown]
# ## OneHotEncoding with categories

# %%
cnts = data['brand'].value_counts()

# %%
data['brand'].nunique() # this function assigns unique values to the column
threshold=100

# %%
rep=cnts[cnts<=threshold].index

# %%
pd.get_dummies(data['brand'].replace(rep,'uncommon')).sample(5)
# Out:
#       BMW  Chevrolet  Ford  Honda  Hyundai  Mahindra  Maruti  Renault  Skoda  \
# 3001    0          0     0      0        1         0       0        0      0
# 2478    0          0     0      0        0         0       0        0      0
# 4601    0          0     0      0        0         0       0        0      1
# 5770    0          0     0      0        0         0       1        0      0
# 4155    0          0     0      0        0         0       0        0      0
#
#       Tata  Toyota  Volkswagen  uncommon
# 3001     0       0           0         0
# 2478     0       1           0         0
# 4601     0       0           0         0
# 5770     0       0           0         0
# 4155     1       0           0         0

# %% [markdown]
# ## Column Transformer

# %%
frame = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/covid.csv')

# %%
frame.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %% [markdown]
# ## As I can see that the data in the fever field has 10 missing values so I need to fill them in order to run my algorithm correctly.

# %%
frame.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %% [markdown]
# # data splitting.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()
x_train_fever = si.fit_transform(x_train[['fever']])

x_test_fever = si.fit_transform(x_test[['fever']])
_train_fever.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-3d23c2305478> in <cell line: 2>()
#       1 si = SimpleImputer()
# ----> 2 x_train_fever = si.fit_transform(x_train[['fever']])
#       3
#       4 x_test_fever = si.fit_transform(x_test[['fever']])
#       5 x_train_fever.shape
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# ...
